# %% [markdown]
# <a href="https://www.kaggle.com/code/fabriciositto/visualization-smokers?scriptVersionId=143038560" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv(r'/kaggle/input/us-smoking-trend/smoking.csv')

# %%
df

# %% [markdown]
# # Preparing and checking the df

# %%
df.describe()

# %%
#change the names to easier code

for i in np.arange(df.columns.size):
    df.rename(columns= { df.columns[i] : df.columns[i].replace("Data",'').replace('.','').replace(' ','') } , inplace=True)
    
df.columns

# %%
df.info() #no nulls

# %%
df.duplicated().sum() # no duplicated

# %% [markdown]
# # All ready to graph

# %% [markdown]
# Para un año en especifico,
# Vamos a intentar un grafico de barras donde:
# *     en el centro esté el nombre del pais,
# *     a la izquierda un grafico de barras horizontales alineadas a la derecha representando la cantidad de hombres fumadores por pais
# *     a la derecha un grafico de barras horizontales alineadas a la izquiera representando la cantidad de mujeres fumadoras por pais
# *     animado con los años
#
# ![example](http://www.dataviz-inspiration.com/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Fworld-mental-health-survey-2.28f9ab60.png&w=1920&q=75)

# %% [markdown]
# ## Paso a paso para después crear el gráfico definitivo

# %%
#preparemos una muestra de la data para simplificar la progrmación del gráfico
ex_data=df[df.Year==1980][['Country','SmokersFemale','SmokersMale']].iloc[1:10].reset_index(drop=True)
ex_data

# %%
#este sería el gráfico con express pero esto no me eprmite combinarlos a psoterior
fig = px.bar(ex_data,x='SmokersFemale',y='Country', range_x=(2500000,0) ,orientation='h', title='Female')

fig.layout.xaxis.title.text=''   
fig.layout.title.x=0.9 

fig.show()

# %%
print(fig)

# %%
data1=go.Bar(
    name='Female',
    x=ex_data['SmokersFemale'],
    y=ex_data['Country'],
    orientation='h',
)

layout1=go.Layout(
    title='Female',
    xaxis=dict(
        title='Smokers',
        range= [np.max(ex_data['SmokersFemale'])*1.1, 0]
    ),
    yaxis=dict(
        title='',
        color='#000'
    )
)

fig1= go.Figure(data=[data1],layout=layout1)
fig1.show()

# %%
data2=go.Bar(
    name='Male',
    x=ex_data['SmokersMale'],
    y=ex_data['Country'],
    orientation='h',
)

layout2=go.Layout(
    title='Male',
    xaxis=dict(
        title='Smokers'
    ),
    yaxis=dict(
        title='',
        color='#000'
    )
)

fig2= go.Figure(data=[data2],layout=layout2)
fig2.show()

# %%
fig_double= make_subplots( 
    rows=1, cols=2,
    column_widths=[0.4,0.4],
    specs=[[{'type':'bar'},{'type':'bar'}]]
    )

fig_double.add_trace(data1,row=1,col=1)


fig_double.add_trace(data2,row=1,col=2)

fig_double.layout.xaxis.range=[2500000,0]
#quitar las etiquetas del grafico izquierdo
#quitar las etiquetas trace
#centrar las etiquetas del grafico derechjo para que queden al medio de todo el grafico

#invertir el rango del grafico de la izquierda

#agregar los titulos

fig_double.show()

# %%
years=df.Year.unique()
years

# %%
#inicimaos la estructura
fig_dict={
    'data':[],
    'layout':{},
    'frames':[]
};

#layout

#create the buttom
fig_dict['layout']['updatemenus'] = [
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]

#DATA
year=years[0]
df_female=df[df.Year==year][['Country','SmokersFemale','SmokersMale']].sort_values(by='SmokersFemale',ascending=False).iloc[1:15].reset_index(drop=True)
data_female=go.Bar(
    name='Female',
    x=df_female['SmokersFemale'],
    y=df_female['Country'],
    orientation='h',
    text=df_female['Country']
)

fig_dict["data"].append(data_female)
    

#FRAMES

for year in years:
    frame = {"data": [], "name": str(year)}
    df_female_by_year=df[df.Year==year][['Country','SmokersFemale','SmokersMale']].sort_values(by='SmokersFemale',ascending=False).iloc[1:15].reset_index(drop=True)
    data_female=go.Bar(
        name='Female',
        x=df_female_by_year['SmokersFemale'],
        y=df_female_by_year['Country'],
        orientation='h',
        text=df_female_by_year['Country']
    )
    frame['data'].append(data_female)
    
    fig_dict['frames'].append(frame)
#armo la figura
    
fig_animated = go.Figure(fig_dict)

fig_animated.show()

# %%
print(fig_double)

# %%
print(fig_animated)

# %% [markdown]
# ## Código definitivo para el gráfico

# %%
#iniciamos la base de la figura

fig_double_animated={
    'data': [],
    'layout':(),
    'frames':[]
}

# %%
#vamos a simplificarnos la vida creando un array de df donde cada df representa el top 10 de un año
years=df.Year.unique()    #todos los años ordenados
dfs_by_years=[]
for year in years:
    df_by_year=df[df.Year==year][['Country','SmokersFemale','SmokersMale','SmokersTotal']].sort_values(by='SmokersTotal',ascending=False).iloc[1:10].reset_index(drop=True).sort_values(by='SmokersTotal',ascending=True)
    dfs_by_years.append(df_by_year)

# %%
# creamos la data

data_fba=[
    go.Bar(
        name='Female',
        x=dfs_by_years[0]['SmokersFemale'],
        y=dfs_by_years[0]['Country'],
        orientation='h',
        text=dfs_by_years[0]['Country'],
        xaxis='x',
        yaxis='y'
    ),
    go.Bar(
        name='Male',
        x=dfs_by_years[0]['SmokersMale'],
        y=dfs_by_years[0]['Country'],
        orientation='h',
        text=dfs_by_years[0]['Country'],
        xaxis='x2',
        yaxis='y2'
    )
]

# agregamos la data a la base
fig_double_animated['data']=data_fba

# %%
# creamos el layout

boton=[
    {
        "buttons": [
            {
                "args": [None, {"frame": {"duration": 500, "redraw": False},
                                "fromcurrent": True, "transition": {"duration": 300,
                                                                    "easing": "quadratic-in-out"}}],
                "label": "Play",
                "method": "animate"
            },
            {
                "args": [[None], {"frame": {"duration": 0, "redraw": False},
                                  "mode": "immediate",
                                  "transition": {"duration": 0}}],
                "label": "Pause",
                "method": "animate"
            }
        ],
        "direction": "left",
        "pad": {"r": 10, "t": 87},
        "showactive": False,
        "type": "buttons",
        "x": 0.1,
        "xanchor": "right",
        "y": 0,
        "yanchor": "top"
    }
]


# integramos el boton con la configuración para ver ambos gráficos

layout_fba={
    'updatemenus': boton,
    'xaxis':{'anchor': 'y', 'domain': [0.0, 0.45], 'range': [ np.max(df[df['Country']!='World']['SmokersMale'])*1.02 , 0 ]},
    'xaxis2': {'anchor': 'y2', 'domain': [0.55, 1.0], 'range': [ 0 , np.max(df[df['Country']!='World']['SmokersMale'])*1.02 ]},
    'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0]},
    'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0]}
}


#agregamos el layout a la base
fig_double_animated['layout']=layout_fba

# %%
#revisamos cómo vamos

fig_test=go.Figure(fig_double_animated)
fig_test.show()

# %%
# creamos el frame

frames_fba=[]

for i in np.arange(len(years)):
    frame={'data':[],'name':str(years[i])}
    data_female=go.Bar(
        name='Female',
        x=dfs_by_years[i]['SmokersFemale'],
        y=dfs_by_years[i]['Country'],
        orientation='h',
        text=dfs_by_years[i]['Country'],
        xaxis='x',
        yaxis='y'
    )
    data_male=go.Bar(
        name='Male',
        x=dfs_by_years[i]['SmokersMale'],
        y=dfs_by_years[i]['Country'],
        orientation='h',
        text=dfs_by_years[i]['Country'],
        xaxis='x2',
        yaxis='y2'
    )
    
    frame['data'].append(data_female)
    frame['data'].append(data_male)
    
    frames_fba.append(frame)

    
# integramos lso frames a la base
fig_double_animated['frames']=frames_fba

# %%
fig_animated=go.Figure(fig_double_animated)
fig_animated.show()

# %% [markdown]
# ## Retoques pendientes
#
# * agregar título
# * eliminar las etiquetas del costado
# * agregar slider por años
# * arreglar los nombres, que aparezcan sólo al medio y estén animados
#
# * translate to English
